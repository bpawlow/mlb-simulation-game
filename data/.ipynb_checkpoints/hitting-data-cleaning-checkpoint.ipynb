# %%
###import packages
import pandas as pd
import uuid

# %%
###Load data from Lahman
fielding_df = pd.read_csv('lahman/fielding.csv')
player_names_df = pd.read_csv('lahman/player_info.csv', encoding='latin-1', usecols= ['playerID', 'nameFirst', 'nameLast'])

player_teams_df = pd.read_csv('lahman/batting.csv', usecols=['playerID', 'yearID', 'teamID'])

franchises_df = pd.read_csv('lahman/franchises.csv')

fielding_df
# Out:
#          playerID  yearID  stint teamID lgID POS    G   GS  InnOuts   PO   A  \
# 0       aardsda01    2004      1    SFN   NL   P   11  0.0     32.0    0   0
# 1       aardsda01    2006      1    CHN   NL   P   45  0.0    159.0    1   5
# 2       aardsda01    2007      1    CHA   AL   P   25  0.0     97.0    2   4
# 3       aardsda01    2008      1    BOS   AL   P   47  0.0    146.0    3   6
# 4       aardsda01    2009      1    SEA   AL   P   73  0.0    214.0    2   5
# ...           ...     ...    ...    ...  ...  ..  ...  ...      ...  ...  ..
# 151502  zwilldu01    1915      1    CHF   FL  OF  148  NaN      NaN  356  20
# 151503  zwilldu01    1916      1    CHN   NL  OF   10  NaN      NaN   11   0
# 151504   zychto01    2015      1    SEA   AL   P   13  1.0     55.0    0   3
# 151505   zychto01    2016      1    SEA   AL   P   12  0.0     41.0    0   0
# 151506   zychto01    2017      1    SEA   AL   P   45  0.0    122.0    1   3
#
#           E  DP  PB  WP  SB  CS  ZR
# 0       0.0   0 NaN NaN NaN NaN NaN
# 1       0.0   1 NaN NaN NaN NaN NaN
# 2       1.0   0 NaN NaN NaN NaN NaN
# 3       0.0   0 NaN NaN NaN NaN NaN
# 4       0.0   1 NaN NaN NaN NaN NaN
# ...     ...  ..  ..  ..  ..  ..  ..
# 151502  8.0   6 NaN NaN NaN NaN NaN
# 151503  0.0   0 NaN NaN NaN NaN NaN
# 151504  0.0   0 NaN NaN NaN NaN NaN
# 151505  1.0   0 NaN NaN NaN NaN NaN
# 151506  0.0   0 NaN NaN NaN NaN NaN
#
# [151507 rows x 18 columns]

# %%
# Filter rows where InnOuts > 500
fielding_df = fielding_df[fielding_df['InnOuts'] > 500]

#trim down columns to only relevant ones, remove pitchers, standarize columns names
fielding_df = fielding_df.loc[fielding_df['POS'] != 'P', ['playerID', 'teamID', 'yearID', 'POS']]
fielding_df = fielding_df.rename(columns={
    'teamID': 'team',
    'yearID': 'year',
    'POS': 'position'
})

fielding_df
# Out:
#          playerID team  year position
# 9       aaronha01  ML1  1954       OF
# 10      aaronha01  ML1  1955       2B
# 11      aaronha01  ML1  1955       OF
# 12      aaronha01  ML1  1956       OF
# 13      aaronha01  ML1  1957       OF
# ...           ...  ...   ...      ...
# 151470  zupcibo01  CHA  1994       OF
# 151478  zuvelpa01  ATL  1985       2B
# 151480  zuvelpa01  ATL  1985       SS
# 151485  zuvelpa01  CLE  1988       SS
# 151499  zwilldu01  CHA  1910       OF
#
# [34284 rows x 4 columns]

# %%
player_names_df
# Out:
#         playerID nameFirst   nameLast
# 0      aardsda01     David    Aardsma
# 1      aaronha01      Hank      Aaron
# 2      aaronto01    Tommie      Aaron
# 3       aasedo01       Don       Aase
# 4       abadan01      Andy       Abad
# ...          ...       ...        ...
# 21005  paysojo99      Joan     Payson
# 21006  galbrjo99      John  Galbreath
# 21007  mcshejo99      John   McSherry
# 21008  weyerle99       Lee      Weyer
# 21009  palerst99     Steve    Palermo
#
# [21010 rows x 3 columns]

# %%
#merge datasets
players_df = fielding_df.merge(player_names_df, how='left', on='playerID')

#Combine names into one column
players_df['name'] = players_df['nameLast'] + ', ' + players_df['nameFirst']
players_df = players_df[['name', 'team', 'year','position']]

#Remove duplicate players
players_df = players_df.drop_duplicates()

players_df
# Out:
#                   name team  year position
# 0          Aaron, Hank  ML1  1954       OF
# 1          Aaron, Hank  ML1  1955       2B
# 2          Aaron, Hank  ML1  1955       OF
# 3          Aaron, Hank  ML1  1956       OF
# 4          Aaron, Hank  ML1  1957       OF
# ...                ...  ...   ...      ...
# 34279      Zupcic, Bob  CHA  1994       OF
# 34280    Zuvella, Paul  ATL  1985       2B
# 34281    Zuvella, Paul  ATL  1985       SS
# 34282    Zuvella, Paul  CLE  1988       SS
# 34283  Zwilling, Dutch  CHA  1910       OF
#
# [34281 rows x 4 columns]

# %%
#load hitting data from Savant
hitting_df = pd.read_csv('savant/hitting-stats.csv')

hitting_df
# Out:
#      last_name, first_name  player_id  year  player_age   ab   pa  hit  \
# 0            Hunter, Torii     116338  2015          39  521  567  125
# 1             Ortiz, David     120074  2015          39  528  614  144
# 2          Rodriguez, Alex     121347  2015          39  523  620  131
# 3          Ramirez, Aramis     133380  2015          37  475  516  117
# 4           Beltré, Adrian     134181  2015          36  567  619  163
# ...                    ...        ...   ...         ...  ...  ...  ...
# 1370      Chourio, Jackson     694192  2024          20  528  573  145
# 1371       Schanuel, Nolan     694384  2024          22  519  607  130
# 1372       Langford, Wyatt     694671  2024          22  499  557  126
# 1373          Young, Jacob     696285  2024          24  468  521  120
# 1374      Merrill, Jackson     701538  2024          21  554  593  162
#
#       single  double  triple  home_run  strikeout  walk  b_gnd_into_dp  \
# 0         81      22       0        22        105    35             14
# 1         70      37       0        37         95    77             16
# 2         75      22       1        33        145    84             17
# 3         68      31       1        17         68    31             23
# 4        109      32       4        18         65    41             18
# ...      ...     ...     ...       ...        ...   ...            ...
# 1370      91      29       4        21        121    39              7
# 1371      98      19       0        13        103    68             14
# 1372      81      25       4        16        115    51              6
# 1373      92      24       1         3        102    30             11
# 1374     101      31       6        24        101    29              2
#
#       b_hit_by_pitch  b_out_fly  b_out_ground  b_out_line_drive  b_out_popup  \
# 0                  6         77           171                29           30
# 1                  0         77           150                48           33
# 2                  6         72           141                22           25
# 3                  5         85           142                48           36
# 4                  3         78           174                68           38
# ...              ...        ...           ...               ...          ...
# 1370               3         75           141                35           14
# 1371               9         72           157                50           15
# 1372               4         86           110                30           35
# 1373              12         48           155                37           17
# 1374               1        117           119                44           19
#
#       b_reached_on_error
# 0                      3
# 1                      5
# 2                      2
# 3                      1
# 4                     10
# ...                  ...
# 1370                   4
# 1371                   2
# 1372                   3
# 1373                   4
# 1374                   3
#
# [1375 rows x 20 columns]

# %%
###merge hitting and player info datasets

#match name columns
hitting_df = hitting_df.rename(columns={'last_name, first_name': 'name'})

#merge
final_df = hitting_df.merge(players_df,'inner',['name', 'year'])

# Count NaN values in each column
missing_values = final_df.isnull().sum()

print(missing_values)

final_df
# Out:
# name                  0
# player_id             0
# year                  0
# player_age            0
# ab                    0
# pa                    0
# hit                   0
# single                0
# double                0
# triple                0
# home_run              0
# strikeout             0
# walk                  0
# b_gnd_into_dp         0
# b_hit_by_pitch        0
# b_out_fly             0
# b_out_ground          0
# b_out_line_drive      0
# b_out_popup           0
# b_reached_on_error    0
# team                  0
# position              0
# dtype: int64
#                    name  player_id  year  player_age   ab   pa  hit  single  \
# 0         Hunter, Torii     116338  2015          39  521  567  125      81
# 1       Ramirez, Aramis     133380  2015          37  475  516  117      68
# 2       Ramirez, Aramis     133380  2015          37  475  516  117      68
# 3        Rollins, Jimmy     276519  2015          36  517  563  116      76
# 4        Pujols, Albert     405395  2015          35  602  661  147      85
# ...                 ...        ...   ...         ...  ...  ...  ...     ...
# 1170  Henderson, Gunnar     683002  2023          22  560  622  143      77
# 1171  Henderson, Gunnar     683002  2023          22  560  622  143      77
# 1172     Volpe, Anthony     683011  2023          22  541  601  113      65
# 1173     Vaughn, Andrew     683734  2023          25  566  615  146      93
# 1174  Yoshida, Masataka     807799  2023          29  537  580  155     104
#
#       double  triple  ...  walk  b_gnd_into_dp  b_hit_by_pitch  b_out_fly  \
# 0         22       0  ...    35             14               6         77
# 1         31       1  ...    31             23               5         85
# 2         31       1  ...    31             23               5         85
# 3         24       3  ...    44             12               0         94
# 4         22       0  ...    50             15               6        109
# ...      ...     ...  ...   ...            ...             ...        ...
# 1170      29       9  ...    56             10               3         76
# 1171      29       9  ...    56             10               3         76
# 1172      23       4  ...    52             10               5         73
# 1173      30       2  ...    36             15              11         81
# 1174      33       3  ...    34             20               7         59
#
#       b_out_ground  b_out_line_drive  b_out_popup  b_reached_on_error  team  \
# 0              171                29           30                   3   MIN
# 1              142                48           36                   1   MIL
# 2              142                48           36                   1   PIT
# 3              154                38           41                   3   LAN
# 4              194                51           41                   5   LAA
# ...            ...               ...          ...                 ...   ...
# 1170           135                30           18                   3   BAL
# 1171           135                30           18                   3   BAL
# 1172           128                39           24                   4   NYA
# 1173           146                34           32                   4   CHA
# 1174           195                31           18                   6   BOS
#
#       position
# 0           OF
# 1           3B
# 2           3B
# 3           SS
# 4           1B
# ...        ...
# 1170        3B
# 1171        SS
# 1172        SS
# 1173        1B
# 1174        OF
#
# [1175 rows x 22 columns]

# %%
### Remove duplicate players with slightly different positions (combine positions into one array)

# Group by 'player_id' and 'year', aggregating the desired columns
final_df = final_df.groupby(["player_id", "year"], as_index=False).agg({
    "position": list,  # Combine the 'position' column into a list
    **{col: "first" for col in final_df.columns if col not in ["player_id", "year", "position"]}  # Take the first value for all other columns
})

# Remove duplicates from the 'position' lists
final_df["position"] = final_df["position"].apply(lambda x: list(set(x)))

# Make all rows / player ids unique 
final_df['player_id'] = [uuid.uuid4() for _ in range(len(final_df))]

#drop ROE since it is not a useful stat
final_df = final_df.drop(columns=['b_reached_on_error'])

print(final_df)
# Out:
#                                 player_id  year  position               name  \
# 0    fdb150e6-1953-44ef-94d4-532dfce449b6  2015      [OF]      Hunter, Torii
# 1    adce2c25-f286-4477-8596-0946b02fbd9a  2015      [3B]    Ramirez, Aramis
# 2    0845d23d-d927-4bec-8b94-e23324cd2fbd  2016      [OF]      Werth, Jayson
# 3    3fb02d6c-c254-471d-badf-f186f12895ac  2015      [SS]     Rollins, Jimmy
# 4    c386e540-371a-4941-be66-220398025427  2016      [2B]       Utley, Chase
# ..                                    ...   ...       ...                ...
# 981  248be0e2-9aac-4199-8174-cbcafab7d043  2023  [3B, SS]  Henderson, Gunnar
# 982  f5272798-78f7-4e03-ab57-2f69ced79b11  2023      [SS]     Volpe, Anthony
# 983  51234acd-7815-40ea-8ade-64b461e1fbe3  2022  [1B, OF]     Vaughn, Andrew
# 984  1741499a-caf3-4b5c-864c-5869cd3885ec  2023      [1B]     Vaughn, Andrew
# 985  1b5ae4e4-77e5-4267-94f9-34065de24dad  2023      [OF]  Yoshida, Masataka
#
#      player_age   ab   pa  hit  single  double  ...  strikeout  walk  \
# 0            39  521  567  125      81      22  ...        105    35
# 1            37  475  516  117      68      31  ...         68    31
# 2            37  525  606  128      79      28  ...        139    71
# 3            36  517  563  116      76      24  ...         86    44
# 4            37  512  565  129      86      26  ...        115    40
# ..          ...  ...  ...  ...     ...     ...  ...        ...   ...
# 981          22  560  622  143      77      29  ...        159    56
# 982          22  541  601  113      65      23  ...        167    52
# 983          24  510  555  138      92      28  ...         96    31
# 984          25  566  615  146      93      30  ...        129    36
# 985          29  537  580  155     104      33  ...         81    34
#
#      b_gnd_into_dp  b_hit_by_pitch  b_out_fly  b_out_ground  b_out_line_drive  \
# 0               14               6         77           171                29
# 1               23               5         85           142                48
# 2               17               4         81           128                40
# 3               12               0         94           154                38
# 4                0              11         73           142                31
# ..             ...             ...        ...           ...               ...
# 981             10               3         76           135                30
# 982             10               5         73           128                39
# 983             13               9         66           152                40
# 984             15              11         81           146                34
# 985             20               7         59           195                31
#
#      b_out_popup  b_reached_on_error  team
# 0             30                   3   MIN
# 1             36                   1   MIL
# 2             27                   3   WAS
# 3             41                   3   LAN
# 4             24                   5   LAN
# ..           ...                 ...   ...
# 981           18                   3   BAL
# 982           24                   4   NYA
# 983           20                   4   CHA
# 984           32                   4   CHA
# 985           18                   6   BOS
#
# [986 rows x 22 columns]

# %%
# Print all the different stats for players
for col in final_df.columns:
    print(col)
# Out:
# player_id
# year
# position
# name
# player_age
# ab
# pa
# hit
# single
# double
# triple
# home_run
# strikeout
# walk
# b_gnd_into_dp
# b_hit_by_pitch
# b_out_fly
# b_out_ground
# b_out_line_drive
# b_out_popup
# b_reached_on_error
# team

# %%
#save to csv and return dataframe
final_df.to_csv("players.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 2
#       1 #save to csv and return dataframe
# ----> 2 final_df.to_csv("players.csv", index=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3466, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3455 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3457 formatter = DataFrameFormatter(
#    3458     frame=df,
#    3459     header=header,
#    (...)
#    3463     decimal=decimal,
#    3464 )
# -> 3466 return DataFrameRenderer(formatter).to_csv(
#    3467     path_or_buf,
#    3468     line_terminator=line_terminator,
#    3469     sep=sep,
#    3470     encoding=encoding,
#    3471     errors=errors,
#    3472     compression=compression,
#    3473     quoting=quoting,
#    3474     columns=columns,
#    3475     index_label=index_label,
#    3476     mode=mode,
#    3477     chunksize=chunksize,
#    3478     quotechar=quotechar,
#    3479     date_format=date_format,
#    3480     doublequote=doublequote,
#    3481     escapechar=escapechar,
#    3482     storage_options=storage_options,
#    3483 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\format.py:1105, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1084     created_buffer = False
#    1086 csv_formatter = CSVFormatter(
#    1087     path_or_buf=path_or_buf,
#    1088     line_terminator=line_terminator,
#    (...)
#    1103     formatter=self.fmt,
#    1104 )
# -> 1105 csv_formatter.save()
#    1107 if created_buffer:
#    1108     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py:237, in CSVFormatter.save(self)
#     233 """
#     234 Create the writer & save.
#     235 """
#     236 # apply compression and byte/text conversion
# --> 237 with get_handle(
#     238     self.filepath_or_buffer,
#     239     self.mode,
#     240     encoding=self.encoding,
#     241     errors=self.errors,
#     242     compression=self.compression,
#     243     storage_options=self.storage_options,
#     244 ) as handles:
#     245
#     246     # Note: self.encoding is irrelevant here
#     247     self.writer = csvlib.writer(
#     248         handles.handle,  # type: ignore[arg-type]
#     249         lineterminator=self.line_terminator,
#    (...)
#     254         quotechar=self.quotechar,
#     255     )
#     257     self._save()
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:702, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     697 elif isinstance(handle, str):
#     698     # Check whether the filename is to be opened in binary mode.
#     699     # Binary mode does not support 'encoding' and 'newline'.
#     700     if ioargs.encoding and "b" not in ioargs.mode:
#     701         # Encoding
# --> 702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#     705             encoding=ioargs.encoding,
#     706             errors=errors,
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
#     711         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'players.csv'
