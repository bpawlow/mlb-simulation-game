# %%
###import packages
import pandas as pd

# %%
#load hitting data from csv
hitting_df = pd.read_csv('hitting-stats.csv')
hitting_df
# Out:
#       last_name, first_name  player_id  year  player_age   ab   pa  hit  \
# 0             Duran, Jarren     680776  2024          27  671  735  191
# 1             Hoerner, Nico     663538  2024          27  582  641  159
# 2    Guerrero Jr., Vladimir     665489  2024          25  616  697  199
# 3             Ramírez, José     608070  2024          31  620  682  173
# 4               Gelof, Zack     680869  2024          24  497  547  105
# ..                      ...        ...   ...         ...  ...  ...  ...
# 124          Burleson, Alec     676475  2024          25  547  595  147
# 125             Winn, Masyn     691026  2024          22  587  637  157
# 126          Volpe, Anthony     683011  2024          23  637  689  155
# 127          Arenado, Nolan     571448  2024          33  578  635  157
# 128           Bregman, Alex     608324  2024          30  581  634  151
#
#      single  double  triple  home_run  strikeout  walk  b_gnd_into_dp  \
# 0       108      48      14        21        160    54              6
# 1       116      35       1         7         66    44              8
# 2       124      44       1        30         96    72             16
# 3        93      39       2        39         82    54              9
# 4        66      20       2        17        188    38              7
# ..      ...     ...     ...       ...        ...   ...            ...
# 124     106      20       0        21         76    35              8
# 125     105      32       5        15        109    41              1
# 126     109      27       7        12        156    42              9
# 127     118      23       0        16         92    44             15
# 128      93      30       2        26         86    44             13
#
#      b_hit_by_pitch  b_out_fly  b_out_ground  b_out_line_drive  b_out_popup  \
# 0                 6         67           172                53           32
# 1                12         86           169                67           35
# 2                 5         71           185                45           22
# 3                 1        124           138                43           64
# 4                 4         65           102                24           20
# ..              ...        ...           ...               ...          ...
# 124               4         98           154                47           31
# 125               1         93           140                55           38
# 126               4         86           179                42           22
# 127               5         90           141                56           46
# 128               5        107           136                48           55
#
#      b_reached_on_error
# 0                    10
# 1                     6
# 2                     2
# 3                     3
# 4                     2
# ..                  ...
# 124                   4
# 125                   3
# 126                   5
# 127                   3
# 128                   3
#
# [129 rows x 20 columns]

# %%
###load player position data
positions_df = pd.read_csv('player-positions.csv')
positions_df = positions_df[['name_fielder', 'fld_name_display_club', 'position']]
positions_df = positions_df.rename(columns={'fld_name_display_club':'team'})
positions_df.head()
# Out:
#         name_fielder    team position
# 0  Stefanic, Michael  Angels       2B
# 1  Stefanic, Michael  Angels       3B
# 2       Sanó, Miguel  Angels       3B
# 3       Sanó, Miguel  Angels       1B
# 4     Moniak, Mickey  Angels       LF

# %%
###merge datasets

#match name columns
hitting_df = hitting_df.rename(columns={'last_name, first_name': 'name'})
positions_df = positions_df.rename(columns={'name_fielder': 'name'})

final_df = hitting_df.merge(positions_df,'inner','name')

#reorder columns
hitting_columns = list(hitting_df.columns)
position_columns = [col for col in final_df.columns if col not in hitting_columns]
reordered_columns = position_columns + hitting_columns
final_df = final_df[reordered_columns]

### Remove duplicate players with slightly different positions (combine positions into one array)

final_df = final_df.groupby("player_id").agg({
    "position": list,             # Combine the 'position' column into a list
    **{col: "first" for col in final_df.columns if col not in ["player_id", "position"]}  # Take the first value for all other columns
}).reset_index()

final_df["position"] = final_df["position"].apply(lambda x: list(set(x)))
    
for position, pos_group in final_df.groupby('position'):
    print(position)
    print(pos_group)
# Out:
# player_id
# position
# team
# name
# year
# player_age
# ab
# pa
# hit
# single
# double
# triple
# home_run
# strikeout
# walk
# b_gnd_into_dp
# b_hit_by_pitch
# b_out_fly
# b_out_ground
# b_out_line_drive
# b_out_popup
# b_reached_on_error
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 27
#      24 for col in final_df.columns:
#      25     print(col)
# ---> 27 for position, pos_group in final_df.groupby('position'):
#      28     print(position)
#      29     print(pos_group)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:740, in BaseGrouper.get_iterator(self, data, axis)
#     729 def get_iterator(
#     730     self, data: FrameOrSeries, axis: int = 0
#     731 ) -> Iterator[tuple[Hashable, FrameOrSeries]]:
#     732     """
#     733     Groupby iterator
#     734
#    (...)
#     738     for each group
#     739     """
# --> 740     splitter = self._get_splitter(data, axis=axis)
#     741     keys = self._get_group_keys()
#     742     for key, group in zip(keys, splitter):
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:754, in BaseGrouper._get_splitter(self, data, axis)
#     745 @final
#     746 def _get_splitter(self, data: FrameOrSeries, axis: int = 0) -> DataSplitter:
#     747     """
#     748     Returns
#     749     -------
#    (...)
#     752     __finalize__ has not been called for the subsetted objects returned.
#     753     """
# --> 754     ids, _, ngroups = self.group_info
#     755     return get_splitter(data, ids, ngroups, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:900, in BaseGrouper.group_info(self)
#     898 @cache_readonly
#     899 def group_info(self):
# --> 900     comp_ids, obs_group_ids = self._get_compressed_codes()
#     902     ngroups = len(obs_group_ids)
#     903     comp_ids = ensure_platform_int(comp_ids)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:924, in BaseGrouper._get_compressed_codes(self)
#     921     return compress_group_index(group_index, sort=self._sort)
#     923 ping = self.groupings[0]
# --> 924 return ping.codes, np.arange(len(ping.group_index))
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:612, in Grouping.codes(self)
#     608 if self._codes is not None:
#     609     # _codes is set in __init__ for MultiIndex cases
#     610     return self._codes
# --> 612 return self._codes_and_uniques[0]
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:670, in Grouping._codes_and_uniques(self)
#     668     else:
#     669         na_sentinel = -1
# --> 670     codes, uniques = algorithms.factorize(
#     671         self.grouping_vector, sort=self._sort, na_sentinel=na_sentinel
#     672     )
#     673 return codes, uniques
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:761, in factorize(values, sort, na_sentinel, size_hint)
#     758     else:
#     759         na_value = None
# --> 761     codes, uniques = factorize_array(
#     762         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     763     )
#     765 if sort and len(uniques) > 0:
#     766     uniques, codes = safe_sort(
#     767         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     768     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\algorithms.py:563, in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     560 hash_klass, values = get_data_algo(values)
#     562 table = hash_klass(size_hint or len(values))
# --> 563 uniques, codes = table.factorize(
#     564     values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     565 )
#     567 codes = ensure_platform_int(codes)
#     568 return codes, uniques
#
# File pandas\_libs\hashtable_class_helper.pxi:5396, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:5310, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# Print all the different stats for players
for col in final_df.columns:
    print(col)
